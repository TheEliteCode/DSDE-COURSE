# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data Arrays 
average_temperature = np.array([5, 8, 11, 13, 18, 24, 24, 28, 32, 36])
solar_output = np.array([2.2, 1.8, 2.5, 3.0, 4.5, 5.3, 5.8, 4.2, 2.5, 4.0])

#Creating the scatter plot
plt.scatter(average_temperature, solar_output)
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Solar Panel Output (kW)')
plt.title('Solar Panel Output vs Average Temperature')
plt.show()

# %%
#Data Arrays 
import numpy as np
from sklearn.linear_model import LinearRegression


annual_rainfall = np.array([800, 1200, 1000, 1500, 1100, 1300, 900, 1400, 950, 1250])
agricultural_yield = np.array([3.2, 4.8, 4.0, 5.5, 4.2, 5.0, 3.5, 5.3, 3.8, 4.9])

# Fitting the model 
model = LinearRegression()
model.fit(annual_rainfall, agricultural_yield)

# Predicting yield for 1150 mm of rainfall
predicted_yield = model.predict(np.array([[1150]]))
print(f"Predicted agricultural yield for 1150 mm of rainfall: {predicted_yield[0]:.2f} tons/hectare")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       9 # Fitting the model
#      10 model = LinearRegression()
# ---> 11 model.fit(annual_rainfall, agricultural_yield)
#      13 # Predicting yield for 1150 mm of rainfall
#      14 predicted_yield = model.predict(np.array([[1150]]))
#
# File c:\Users\davod\OneDrive\Desktop\DSDE COURSE\.venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# ...
