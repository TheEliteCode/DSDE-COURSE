# %%
def func(**kw):
    print(kw)

func(a=1, b=2, c=3)
# Output: {'a': 1, 'b': 2, 'c':
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
def show_student(**details):
    for key, value in details.items():
        print(f"{key}: {value}")

show_student(name="Daniel", age=22, school="UNILAG")
# Out:
# name: Daniel
# age: 22
# school: UNILAG
