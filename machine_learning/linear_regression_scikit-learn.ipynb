# %%
import pandas as pd

# %%
import random

# %%
import numpy as np

# %%
data = []

for _ in range(500):
    team_name = f"Team {chr(random.randint(65,90))}"
    season = random.randint(2010, 2023)
    wins = random.randint(50, 110)
    losses = 162 - wins
    hits = random.randint(1200, 1600)
    doubles = random.randint(200, 350)
    triples = random.randint(10, 40)
    home_runs = random.randint(100, 250)
    strikeouts = random.randint(1000, 1500)

    hits_adjusted = hits + (wins-80) * 5
    doubles_adjusted = doubles + (wins-80) * 3
    triples_adjusted = triples + (wins-80)
    home_runs_adjusted = home_runs + (wins-80) * 3
    strikeouts_adjusted = strikeouts - (wins-80) * 3
    data.append([team_name, season, wins, losses, hits_adjusted, doubles_adjusted, triples_adjusted, home_runs_adjusted, strikeouts_adjusted])

# %%
columns = ["Team_Name", "Season", "Wins", "Losses", "Hits", "Doubles", "Triples", "Home_Runs", "Strikeouts"]

# %%
df = pd.DataFrame(data, columns=columns)

# %%
df.head()
# Out:
#   Team_Name  Season  Wins  Losses  Hits  Doubles  Triples  Home_Runs  \
# 0    Team M    2018    97      65  1440      348       43        262
# 1    Team H    2014    66      96  1407      256       13        201
# 2    Team W    2018    97      65  1486      281       39        220
# 3    Team Q    2012   103      59  1424      359       43        313
# 4    Team O    2018    84      78  1230      213       17        153
#
#    Strikeouts
# 0        1106
# 1        1456
# 2        1408
# 3        1019
# 4        1320
